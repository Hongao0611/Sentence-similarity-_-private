# %% [markdown]
# Import the operating system, and check that you are in the correct directory

# %%
import os

# %%
pwd
# Out:
# '/Users/tim_home/Dropbox/My Documents/Projects/Hobbit_test/hobbit_code'

# %% [markdown]
# import BERTopic and hdbscan

# %%
from bertopic import BERTopic

# %%
import hdbscan

# %% [markdown]
# Import pandas for data frames and numpy for numerical operations

# %%
# for data frames and numerical manipulation
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 100)

# %% [markdown]
# Import various visualization libraries

# %%
# for visualization
import plotly.express as px
import plotly.graph_objects as go
import matplotlib.pyplot as plt
import plotly.io as pio
pio.renderers.default='iframe'

# %% [markdown]
# Import Networkx

# %%
import networkx as nx
from networkx.algorithms import bipartite

# %% [markdown]
# Import BERTopic

# %%
# using BERTopic
from bertopic import BERTopic

# %% [markdown]
# Load the saved model

# %%
# load the saved model
hobbit_topic_model = BERTopic.load('hobbit_model')

# check the model is properly loaded
hobbit_topic_model.get_topic_info()
# Out:
#     Topic  Count                                         Name
# 0      -1    409                             -1_be_if_are_you
# 1       0     60              0_gollum_precious_yes_pocketses
# 2       1     49                      1_goblins_goblin_lad_ho
# 3       2     46              2_gandalf_baggins_mr_adventures
# 4       3     37                 3_dragon_arrow_smaug_dragons
# 5       4     31                   4_mountain_king_under_rich
# 6       5     31                   5_thorin_stairs_dwarf_fili
# 7       6     25                 6_important_thorin_rats_sure
# 8       7     24                        7_boat_rope_hook_fili
# 9       8     23                 8_gandalf_horse_sending_path
# 10      9     22           9_spider_spiders_attercop_tomnoddy
# 11     10     21               10_light_redder_bottom_climbed
# 12     11     20                 11_eagles_eagle_lord_swooped
# 13     12     20             12_river_flowed_watergate_stream
# 14     13     20                   13_bard_master_girion_king
# 15     14     20                    14_ponies_pony_slung_rain
# 16     15     20             15_arkenstone_treasure_gold_coat
# 17     16     18                      16_bert_william_tom_yer
# 18     17     15                 17_tunnel_doorstep_sh_echoes
# 19     18     15           18_leaves_treetrunks_twilight_path
# 20     19     15                 19_wolves_flames_fire_sparks
# 21     20     15                    20_smaug_riddling_doze_am
# 22     21     15                 21_yes_goblins_durstnt_dells
# 23     22     14                     22_am_baggins_mr_depends
# 24     23     14                   23_sleep_dreams_dream_wake
# 25     24     13              24_torches_thirst_warnings_drip
# 26     25     13                  25_troop_possibly_we_goblin
# 27     26     13                26_people_heroes_wise_killing
# 28     27     11                  27_elfking_dain_will_depart
# 29     28     10              28_precise_er_dragongold_throng
# 30     29      9                29_cloud_flight_winds_country
# 31     30      8              30_drove_assault_shouting_crack
# 32     31      8                31_please_hates_plates_nights
# 33     32      8          32_elrond_midsummers_banner_written
# 34     33      7           33_burglar_burglars_burgling_trunk
# 35     34      7                    34_thrush_bird_breed_carc
# 36     35      7                  35_send_plight_miles_advice
# 37     36      7       36_fireworks_parties_everybody_gandalf
# 38     37      7                37_below_disturbed_slope_bits
# 39     38      7                    38_boys_sing_burn_foolish
# 40     39      6       39_conspirator_audacious_spoons_daring
# 41     40      6         40_glummer_pitchdark_wandered_primly
# 42     41      6               41_mirkwood_nuts_north_carrock
# 43     42      5         42_spiders_attercop_knives_pokedthat
# 44     43      5  43_cheerily_ambling_emptyhanded_hobbitlands

# %%
hobbit_df = pd.read_csv('./hobbit_docinfo.csv', index_col = 0)
